# %%
import numpy as np
import pandas as pd
import yfinance as yf
import sys
import os

# Add the utils folder to the path
sys.path.append(os.path.abspath("../utils"))

from quant_functions import (
    compute_log_returns,
    portfolio_return,
    portfolio_std,
    random_portfolio_performance,
    global_min_variance,
    max_sharpe_ratio,
    efficient_frontier,
    plot_efficient_frontier
)

# %%
data = yf.download(tickers, start="2020-01-01", auto_adjust=True)
prices = data["Close"]
prices.tail()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Ticker            AAPL        AMZN       GOOGL        MSFT
# Date
# 2025-11-21  271.489990  220.690002  299.660004  472.119995
# 2025-11-24  275.920013  226.279999  318.579987  474.000000
# 2025-11-25  276.970001  229.669998  323.440002  476.989990
# 2025-11-26  277.549988  229.160004  319.950012  485.500000
# 2025-11-28  278.850006  233.220001  320.179993  492.010010

# %%
returns = compute_log_returns(prices)
returns.tail()
# Out:
# Ticker          AAPL      AMZN     GOOGL      MSFT
# Date
# 2025-11-21  0.019490  0.016217  0.034666 -0.013277
# 2025-11-24  0.016186  0.025014  0.061225  0.003974
# 2025-11-25  0.003798  0.014870  0.015140  0.006288
# 2025-11-26  0.002092 -0.002223 -0.010849  0.017684
# 2025-11-28  0.004673  0.017562  0.000719  0.013320

# %%
plot_efficient_frontier(returns)
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_efficient_frontier(returns)
#
# File ~\Desktop\quant_lab\utils\quant_functions.py:204, in plot_efficient_frontier(returns)
#     202 # Optimization results
#     203 gmv = global_min_variance(returns)
# --> 204 msr = max_sharpe_ratio(returns)
#     206 gmv_ret = portfolio_return(gmv, returns)
#     207 gmv_vol = portfolio_std(gmv, returns)
#
# File ~\Desktop\quant_lab\utils\quant_functions.py:140, in max_sharpe_ratio(returns, risk_free_rate)
#     137 constraints = [cp.sum(w) == 1, w >= 0]
#     139 prob = cp.Problem(objective, constraints)
# --> 140 prob.solve()
#     142 return w.value
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\problems\problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\problems\problem.py:1191, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1188         self.unpack(chain.retrieve(soln))
#    1189         return self.value
# -> 1191 data, solving_chain, inverse_data = self.get_problem_data(
#    1192     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1193 )
#    1195 if verbose:
#    1196     print(_NUM_SOLVER_STR)
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\problems\problem.py:755, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     753 if key != self._cache.key:
#     754     self._cache.invalidate()
# --> 755     solving_chain = self._construct_chain(
#     756         solver=solver, gp=gp,
#     757         enforce_dpp=enforce_dpp,
#     758         ignore_dpp=ignore_dpp,
#     759         canon_backend=canon_backend,
#     760         solver_opts=solver_opts)
#     761     self._cache.key = key
#     762     self._cache.solving_chain = solving_chain
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\problems\problem.py:1009, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#    1007 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#    1008 self._sort_candidate_solvers(candidate_solvers)
# -> 1009 return construct_solving_chain(self, candidate_solvers, gp=gp,
#    1010                                enforce_dpp=enforce_dpp,
#    1011                                ignore_dpp=ignore_dpp,
#    1012                                canon_backend=canon_backend,
#    1013                                solver_opts=solver_opts,
#    1014                                specified_solver=solver)
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:232, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts, specified_solver)
#     230 if len(problem.variables()) == 0:
#     231     return SolvingChain(reductions=[ConstantSolver()])
# --> 232 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     234 # Process DPP status of the problem.
#     235 dpp_context = 'dcp' if not gp else 'dgp'
#
# File C:\ProgramData\anaconda3\envs\quant_lab\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:147, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     144     elif problem.is_dqcp():
#     145         append += ("\nHowever, the problem does follow DQCP rules. "
#     146                    "Consider calling solve() with `qcp=True`.")
# --> 147     raise DCPError(
#     148         "Problem does not follow DCP rules. Specifically:\n" + append)
#     149 elif gp and not problem.is_dgp():
#     150     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The objective is not DCP. Its following subexpressions are not:
# power(QuadForm(var31, [[0.10 0.07 0.07 0.07]
#  [0.07 0.13 0.07 0.07]
#  [0.07 0.07 0.11 0.07]
#  [0.07 0.07 0.07 0.09]]), 0.5)
